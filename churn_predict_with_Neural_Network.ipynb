# %% [markdown]
# <a href="https://colab.research.google.com/github/sohag221/Deep-Learning/blob/main/churn_predict_with_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: load tensorflow and keras.

# !pip install tensorflow
import tensorflow as tf
from tensorflow import keras
print(tf.__version__)
keras.__version__
# Out:
# ...
# 2.18.0
# '3.8.0'

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler , LabelEncoder , OneHotEncoder
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import load_model

# %%
data = pd.read_csv('/content/drive/MyDrive/Statistical dataset/Customer_churn_Prediction(Internet user).csv')
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.shape
# Out:
# (7043, 21)

# %%
data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
data = data.drop(['customerID'] , axis = 1)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for col in data.columns:
  if data[col].dtype == 'object':
    data[col] = le.fit_transform(data[col])

# %%
data
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
X = data.drop(['Churn'] , axis = 1)
y = data['Churn']

# %%
scalar = StandardScaler()
X=scalar.fit_transform(X)

# %%
data.corr()
# Out:
#                     gender  SeniorCitizen   Partner  Dependents    tenure  \
# gender            1.000000      -0.001492 -0.001808    0.010517  0.005095
# SeniorCitizen    -0.001492       1.000000  0.016101   -0.211362  0.016090
# Partner          -0.001808       0.016101  1.000000    0.452676  0.379689
# Dependents        0.010517      -0.211362  0.452676    1.000000  0.159722
# tenure            0.005095       0.016090  0.379689    0.159722  1.000000
# PhoneService     -0.006488       0.008699  0.017706   -0.001762  0.008445
# MultipleLines    -0.006739       0.145751  0.142410   -0.024991  0.343022
# InternetService  -0.000863      -0.032754  0.000891    0.044590 -0.030361
# OnlineSecurity   -0.015017      -0.128530  0.150828    0.152166  0.325455
# OnlineBackup     -0.012057      -0.014024  0.153130    0.091015  0.370866
# DeviceProtection  0.000549      -0.021786  0.166330    0.080537  0.371121
# TechSupport      -0.006825      -0.151571  0.126733    0.133524  0.322956
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42,stratify=y)

# %%
x_train.shape
# Out:
# (4930, 19)

# %%
x_train[0]
# Out:
# array([-1.00955867, -0.44014635, -0.96662231, -0.65401193, -1.11456292,
#         0.32743831, -0.9915883 ,  0.17225018, -0.91883775, -1.02991925,
#        -1.02791014, -0.92526212,  1.14622038, -1.12140513, -0.8282069 ,
#        -1.20511329,  0.39855772,  0.51310666,  0.01493513])

# %% [markdown]
# **Model Creat**

# %%
model = Sequential([
    Dense (units=32, activation='relu', input_dim=len(x_train[1])),
    Dense (units=64, activation='relu'),
    Dense (units=32, activation='relu'),
    Dense (units=1, activation='sigmoid')]
)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),
    epochs=10,
    batch_size=100
)
# Out:
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8100 - loss: 0.4126 - val_accuracy: 0.7889 - val_loss: 0.4341
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8163 - loss: 0.4010 - val_accuracy: 0.7795 - val_loss: 0.4364
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8116 - loss: 0.4031 - val_accuracy: 0.7922 - val_loss: 0.4333
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8299 - loss: 0.3804 - val_accuracy: 0.7842 - val_loss: 0.4346
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8254 - loss: 0.3939 - val_accuracy: 0.7875 - val_loss: 0.4366
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8190 - loss: 0.4002 - val_accuracy: 0.7856 - val_loss: 0.4371
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8263 - loss: 0.3745 - val_accuracy: 0.7847 - val_loss: 0.4403
# Epoch 8/10
# ...

# %%
model.evaluate(x_test,y_test)
# Out:
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7783 - loss: 0.4493
# [0.4408949613571167, 0.7832465767860413]

# %%
y_pred = model.predict(x_test)
y_pred = y_pred > 0.5
# Out:
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
y_pred
# Out:
# array([[ True],
#        [False],
#        [ True],
#        ...,
#        [False],
#        [ True],
#        [False]])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.86      1552
#            1       0.60      0.54      0.57       561
#
#     accuracy                           0.78      2113
#    macro avg       0.72      0.71      0.71      2113
# weighted avg       0.78      0.78      0.78      2113

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[1351,  201],
#        [ 257,  304]])
